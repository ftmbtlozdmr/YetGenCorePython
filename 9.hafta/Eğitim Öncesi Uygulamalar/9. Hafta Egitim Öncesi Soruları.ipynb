# %% [markdown]
# # Problem 1
# Vehicle sınıfından miras alan bir Bus sınıfı oluşturun. Bus.seating_capacity()'nin kapasite bağımsız değişkenine varsayılan olarak 50 değerini verin.
#
# ```
# Output:
# > The seating capacity of a bus is 50 passengers
# ```

# %%
# 1.Problemin Çözümünü Buraya Yazınız
class Vehicle:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
class Bus(Vehicle):
    def seating_capacity(self, capacity=50):
        print(f"The seating capacity of a bus is {capacity} passengers")
        
bus = Bus("Mercedes", "Sprinter", 2021)
bus.seating_capacity()
# Out:
# The seating capacity of a bus is 50 passengers

# %% [markdown]
# # Problem 2
#
#
# School_bus'ın aynı zamanda Vehicle sınıfının bir örneği olup olmadığını belirleyiniz.

# %%
# 2.Problemin Çözümünü Buraya Yazınız

print(isinstance(bus, Vehicle))
print(isinstance(School_bus, Vehicle))
# Out:
# True
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 # 2.Problemin Çözümünü Buraya Yazınız
#       3 print(isinstance(bus, Vehicle))
# ----> 4 print(isinstance(School_bus, Vehicle))
#
# NameError: name 'School_bus' is not defined
